# %%
# The Notebook was created to complete the final capstone project

# %%
import pandas as pd
import numpy as np

# %%
cap_proj = "Hello Capstone Project Course!"
print (cap_proj)
# Out:
# Hello Capstone Project Course!
